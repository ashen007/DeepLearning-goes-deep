# %%
import PIL.Image
import tensorflow as tf

from tensorflow.keras.utils import array_to_img
from matplotlib import pyplot as plt

# %% [markdown]
# ### Load testing image

# %%
image = PIL.Image.open('../../data/cdcb4ee18d2a72543e842a11d919fe12.jpg')
image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=564x765 at 0x222350EA640>

# %% [markdown]
# ## Horizontal flip

# %%
figure, axes = plt.subplots(nrows=1, ncols=2, figsize=[12,6], dpi=300)

axes[0].imshow(image)
axes[0].set_title('original')
axes[1].imshow(array_to_img(tf.image.flip_left_right(image)))
axes[1].set_title('transformed')

plt.show()
