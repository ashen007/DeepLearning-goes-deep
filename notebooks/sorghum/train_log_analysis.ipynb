# %%
import numpy as np
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt

# %%
log_history = pd.read_pickle('submission/9/history.pkl')
log_history_2i = pd.read_pickle('submission/9/history-2nd-iter.pkl')
log_history_1 = pd.read_pickle('submission/10/history.pkl')
log_history_1_2nd = pd.read_pickle('submission/10/history-2nd-iter.pkl')

# %%
plt.figure(figsize=[12,6], dpi=300)
sns.lineplot(x=range(log_history.shape[0]),y=np.log(log_history.loss),label='loss', color='#590242')
sns.lineplot(x=range(log_history_2i.shape[0],log_history_2i.shape[0]*2),y=np.log(log_history_2i.loss),label='loss 2nd iter', color='#590242', linestyle='--')
sns.lineplot(x=range(log_history.shape[0]),y=np.log(log_history.val_loss),label='val loss', color='#F2522E')
sns.lineplot(x=range(log_history_2i.shape[0],log_history_2i.shape[0]*2),y=np.log(log_history_2i.val_loss),label='val loss 2nd iter', color='#F2522E', linestyle='--')
plt.show()

# %%
plt.figure(figsize=[12,6], dpi=300)
sns.lineplot(x=range(log_history.shape[0]),y=log_history.accuracy,label='accuracy', color='#590242')
sns.lineplot(x=range(log_history_2i.shape[0],log_history_2i.shape[0]*2),y=log_history_2i.accuracy,label='loss 2nd iter', color='#590242', linestyle='--')
sns.lineplot(x=range(log_history.shape[0]),y=log_history.val_accuracy,label='val accuracy', color='#F2522E')
sns.lineplot(x=range(log_history_2i.shape[0],log_history_2i.shape[0]*2),y=log_history_2i.val_accuracy,label='val loss 2nd iter', color='#F2522E', linestyle='--')
plt.show()

# %%
plt.figure(figsize=[12,6], dpi=300)
sns.lineplot(x=range(log_history.shape[0]),y=np.log(log_history.lr),label='learning rate')
plt.show()

# %% [markdown]
# ## with more data to train (after 45 iterations)

# %%
log_history_1
# Out:
#         loss  accuracy   val_loss  val_accuracy        lr
# 0   4.036809  0.075413   4.775715      0.013906  0.001000
# 1   3.317362  0.180132   5.580054      0.013281  0.001000
# 2   2.977950  0.245113   5.971272      0.010703  0.001000
# 3   2.739097  0.293864   4.830152      0.011797  0.001000
# 4   2.561497  0.330368   5.652667      0.011875  0.001000
# 5   2.416212  0.361964   8.513062      0.007891  0.001000
# 6   2.059766  0.443460   5.859508      0.028438  0.000316
# 7   1.941176  0.473180   4.944977      0.014375  0.000316
# 8   1.861187  0.491343   5.276630      0.012578  0.000316
# 9   1.806434  0.505197   5.420305      0.009609  0.000316
# 10  1.754029  0.519084  19.661314      0.011953  0.000316
# 11  1.625250  0.549571  12.314491      0.015469  0.000100
# 12  1.576375  0.562766   3.075552      0.292109  0.000100
# 13  1.556174  0.568549  28.111223      0.006328  0.000100
# 14  1.519237  0.576073   9.079198      0.060625  0.000100
# ...

# %%
plt.figure(figsize=[12,6], dpi=300)
sns.lineplot(x=range(log_history_1.shape[0]),y=np.log(log_history_1.loss),label='loss', color='#590242')
sns.lineplot(x=range(log_history_1_2nd.shape[0],log_history_1_2nd.shape[0]*2),y=np.log(log_history_1_2nd.loss),label='loss 2nd iter', color='#590242', linestyle='--')
sns.lineplot(x=range(log_history_1.shape[0]),y=np.log(log_history_1.val_loss),label='val loss', color='#F2522E')
sns.lineplot(x=range(log_history_1_2nd.shape[0],log_history_1_2nd.shape[0]*2),y=np.log(log_history_1_2nd.val_loss),label='val loss 2nd iter', color='#F2522E', linestyle='--')
plt.show()

# %%
plt.figure(figsize=[12,6], dpi=300)
sns.lineplot(x=range(log_history_1.shape[0]),y=log_history_1.accuracy,label='accuracy', color='#590242')
sns.lineplot(x=range(log_history_1_2nd.shape[0],log_history_1_2nd.shape[0]*2),y=log_history_1_2nd.accuracy,label='loss 2nd iter', color='#590242', linestyle='--')
sns.lineplot(x=range(log_history_1.shape[0]),y=log_history_1.val_accuracy,label='val accuracy', color='#F2522E')
sns.lineplot(x=range(log_history_1_2nd.shape[0],log_history_1_2nd.shape[0]*2),y=log_history_1_2nd.val_accuracy,label='val loss 2nd iter', color='#F2522E', linestyle='--')
plt.show()

# %%
plt.figure(figsize=[12,6], dpi=300)
sns.lineplot(x=range(log_history_1.shape[0]),y=log_history_1.lr,label='learning rate')
plt.show()
