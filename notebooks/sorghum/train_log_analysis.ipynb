# %%
import numpy as np
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt

# %%
log_history = pd.read_pickle('submission/9/history.pkl')
log_history
# Out:
#         loss  accuracy    val_loss  val_accuracy        lr
# 0   4.037889  0.077788    5.179511      0.012249  0.001000
# 1   3.275724  0.187435    7.701500      0.012477  0.001000
# 2   2.870328  0.263922    5.035071      0.011032  0.001000
# 3   2.591836  0.321359  301.457611      0.007380  0.001000
# 4   2.365671  0.370930    5.513903      0.011108  0.001000
# ..       ...       ...         ...           ...       ...
# 70  0.420164  0.871625    0.768211      0.800213  0.000003
# 71  0.422694  0.870062    0.593226      0.840079  0.000003
# 72  0.421959  0.870797    0.696384      0.818016  0.000003
# 73  0.422418  0.871281    0.581898      0.843351  0.000003
# 74  0.418046  0.872923    0.520192      0.856056  0.000003
#
# [75 rows x 5 columns]

# %%
plt.figure(figsize=[12,6], dpi=300)
sns.lineplot(x=range(log_history.shape[0]),y=np.log(log_history.loss),label='loss')
sns.lineplot(x=range(log_history.shape[0]),y=np.log(log_history.val_loss),label='val loss')
plt.show()

# %%
plt.figure(figsize=[12,6], dpi=300)
sns.lineplot(x=range(log_history.shape[0]),y=np.log(log_history.accuracy),label='accuracy')
sns.lineplot(x=range(log_history.shape[0]),y=np.log(log_history.val_accuracy),label='val accuracy')
plt.show()

# %%
plt.figure(figsize=[12,6], dpi=300)
sns.lineplot(x=range(log_history.shape[0]),y=np.log(log_history.lr),label='learning rate')
plt.show()

# %%
plt.figure(figsize=[12,6], dpi=300)
sns.lineplot(x=range(log_history.shape[0]),y=np.log(log_history.lr),label='learning rate')
plt.show()
